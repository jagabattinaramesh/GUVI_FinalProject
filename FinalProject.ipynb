# %%
# Final Project

# %%
import pandas as pd

# %%
df=pd.read_excel("train.xlsx",index_col='Loan_ID')

# %%
df.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No        0.0      Graduate            No
# LP001003   Male     Yes        1.0      Graduate            No
# LP001005   Male     Yes        0.0      Graduate           Yes
# LP001006   Male     Yes        0.0  Not Graduate            No
# LP001008   Male      No        0.0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002           5849.0                0.0         NaN             360.0
# LP001003           4583.0             1508.0       128.0             360.0
# LP001005           3000.0                0.0        66.0             360.0
# LP001006           2583.0             2358.0       120.0             360.0
# LP001008           6000.0                0.0       141.0             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002             1.0         Urban           Y
# ...

# %%
df.shape
# Out:
# (614, 12)

# %%
test=pd.read_excel("test.xlsx",index_col="Loan_ID")
test.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001015   Male     Yes        0.0      Graduate            No
# LP001022   Male     Yes        1.0      Graduate            No
# LP001031   Male     Yes        2.0      Graduate            No
# LP001035   Male     Yes        2.0      Graduate            No
# LP001051   Male      No        0.0  Not Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001015           5720.0                0.0       110.0             360.0
# LP001022           3076.0             1500.0       126.0             360.0
# LP001031           5000.0             1800.0       208.0             360.0
# LP001035           2340.0             2546.0       100.0             360.0
# LP001051           3276.0                0.0        78.0             360.0
#
#           Credit_History Property_Area
# Loan_ID
# LP001015             1.0         Urban
# ...

# %%
test.shape
# Out:
# (367, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 614 entries, LP001002 to LP002990
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             601 non-null    object
#  1   Married            611 non-null    object
#  2   Dependents         599 non-null    object
#  3   Education          614 non-null    object
#  4   Self_Employed      582 non-null    object
#  5   ApplicantIncome    614 non-null    float64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         592 non-null    float64
#  8   Loan_Amount_Term   600 non-null    float64
#  9   Credit_History     564 non-null    float64
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
# dtypes: float64(5), object(7)
# memory usage: 62.4+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df["Credit_History"].value_counts()
# Out:
# 1.0    475
# 0.0     89
# Name: Credit_History, dtype: int64

# %%
df["Loan_Amount_Term"].value_counts()
# Out:
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 240.0      4
# 84.0       4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: Loan_Amount_Term, dtype: int64

# %%
df["Credit_History"]=df.Credit_History.astype(object)
df["Loan_Amount_Term"]=df.Loan_Amount_Term.astype(object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 614 entries, LP001002 to LP002990
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             601 non-null    object
#  1   Married            611 non-null    object
#  2   Dependents         599 non-null    object
#  3   Education          614 non-null    object
#  4   Self_Employed      582 non-null    object
#  5   ApplicantIncome    614 non-null    float64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         592 non-null    float64
#  8   Loan_Amount_Term   600 non-null    object
#  9   Credit_History     564 non-null    object
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
# dtypes: float64(3), object(9)
# memory usage: 62.4+ KB

# %%
df_numeric=df.select_dtypes(exclude=object)

# %%
df_numeric.head()
# Out:
#           ApplicantIncome  CoapplicantIncome  LoanAmount
# Loan_ID
# LP001002           5849.0                0.0         NaN
# LP001003           4583.0             1508.0       128.0
# LP001005           3000.0                0.0        66.0
# LP001006           2583.0             2358.0       120.0
# LP001008           6000.0                0.0       141.0

# %%
df_cat=df.select_dtypes(include=object)
df_cat.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No        0.0      Graduate            No
# LP001003   Male     Yes        1.0      Graduate            No
# LP001005   Male     Yes        0.0      Graduate           Yes
# LP001006   Male     Yes        0.0  Not Graduate            No
# LP001008   Male      No        0.0      Graduate            No
#
#          Loan_Amount_Term Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002            360.0            1.0         Urban           Y
# LP001003            360.0            1.0         Rural           N
# LP001005            360.0            1.0         Urban           Y
# LP001006            360.0            1.0         Urban           Y
# LP001008            360.0            1.0         Urban           Y

# %%
# Imputing Numerical Columns

# %%
df_numeric.isnull().sum()
# Out:
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# dtype: int64

# %%
df_numeric.LoanAmount.value_counts()
# Out:
# 120.0    20
# 110.0    17
# 100.0    15
# 160.0    12
# 187.0    12
#          ..
# 240.0     1
# 214.0     1
# 59.0      1
# 166.0     1
# 253.0     1
# Name: LoanAmount, Length: 203, dtype: int64

# %%
import seaborn as sns
sns.boxplot(df_numeric.LoanAmount)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.distplot(df_numeric.LoanAmount)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_numeric.LoanAmount.median()
# Out:
# 128.0

# %%
df_numeric['LoanAmount'] = df_numeric['LoanAmount'].fillna(df_numeric['LoanAmount'].median())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_numeric.isnull().sum()
# Out:
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# dtype: int64

# %%
# Imputing Categorical Columns

# %%
df_cat.isnull().sum()
# Out:
# Gender              13
# Married              3
# Dependents          15
# Education            0
# Self_Employed       32
# Loan_Amount_Term    14
# Credit_History      50
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df_cat.Credit_History.value_counts()
# Out:
# 1.0    475
# 0.0     89
# Name: Credit_History, dtype: int64

# %%
df_cat.Self_Employed.value_counts()
# Out:
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64

# %%
# ChiSqR_Test on two categorical columns
from scipy.stats import chi2_contingency

def ChiSqR_Test(cat_1,cat_2):
  # Cross tabulation between cat_1 and cat_2
  CrosstabResult=pd.crosstab(index=df_cat[cat_1],columns=df_cat[cat_2])
  print(CrosstabResult)
  # Performing Chi-sq test
  ChiSqResult = chi2_contingency(CrosstabResult)
  # P-Value is the Probability of H0 being True
  # If P-Value is greater than 0.05 then only we Accept the assumption(H0)
  return (print('The P-Value of the ChiSq Test is:', ChiSqResult[1]))

# %%
ChiSqR_Test('Property_Area','Loan_Status')
# Out:
# Loan_Status     N    Y
# Property_Area
# Rural          69  110
# Semiurban      54  179
# Urban          69  133
# The P-Value of the ChiSq Test is: 0.0021360187811644937

# %%
column_names=df_cat.columns.tolist()
column_names
# Out:
# ['Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area',
#  'Loan_Status']

# %%
for i in column_names:
  print("ChiSqR_Test between "+ i +" and Loan_Status-->")
  ChiSqR_Test(i,'Loan_Status')
  print('\n')
# Out:
# ChiSqR_Test between Gender and Loan_Status-->
# Loan_Status    N    Y
# Gender
# Female        37   75
# Male         150  339
# The P-Value of the ChiSq Test is: 0.7086529816451106
#
#
# ChiSqR_Test between Married and Loan_Status-->
# Loan_Status    N    Y
# Married
# No            79  134
# Yes          113  285
# The P-Value of the ChiSq Test is: 0.03439381301579988
#
#
# ChiSqR_Test between Dependents and Loan_Status-->
# Loan_Status    N    Y
# Dependents
# 0.0          107  238
# 1.0           36   66
# 2.0           25   76
# 3+            18   33
# The P-Value of the ChiSq Test is: 0.3678506740863211
#
#
# ChiSqR_Test between Education and Loan_Status-->
# Loan_Status     N    Y
# Education
# Graduate      140  340
# Not Graduate   52   82
# The P-Value of the ChiSq Test is: 0.04309962129357355
#
#
# ChiSqR_Test between Self_Employed and Loan_Status-->
# Loan_Status      N    Y
# Self_Employed
# No             157  343
# Yes             26   56
# ...

# %%
df_cat[(df_cat["Credit_History"].isnull()) & (df_cat["Self_Employed"] == 'Yes')]
# Out:
#           Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001264    Male     Yes         3+  Not Graduate           Yes
# LP001469    Male      No        0.0      Graduate           Yes
# LP001788  Female      No        0.0      Graduate           Yes
# LP002008    Male     Yes        2.0      Graduate           Yes
# LP002444    Male      No        1.0  Not Graduate           Yes
# LP002478     NaN     Yes        0.0      Graduate           Yes
# LP002522  Female      No        0.0      Graduate           Yes
#
#          Loan_Amount_Term Credit_History Property_Area Loan_Status
# Loan_ID
# LP001264            360.0            NaN     Semiurban           Y
# LP001469            480.0            NaN         Urban           Y
# LP001788            360.0            NaN         Urban           Y
# LP002008             84.0            NaN         Rural           Y
# LP002444            360.0            NaN     Semiurban           N
# ...

# %%
X=df_cat[(df_cat["Credit_History"].isnull()) & (df_cat["Loan_Status"] == 'Y')]
X.shape
# Out:
# (37, 9)

# %%
# Imputation of categorical features

# %%
df_cat.isnull().sum()
# Out:
# Gender              13
# Married              3
# Dependents          15
# Education            0
# Self_Employed       32
# Loan_Amount_Term    14
# Credit_History      50
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
Index_L1=df_cat.index[(df_cat["Credit_History"].isnull()) & (df_cat["Loan_Status"]=='Y')]

# %%
Index_L2=df_cat.index[(df_cat["Credit_History"].isnull()) & (df_cat["Loan_Status"]=='N')]

# %%
Index_L1
# Out:
# Index(['LP001034', 'LP001123', 'LP001264', 'LP001280', 'LP001405', 'LP001443',
#        'LP001469', 'LP001541', 'LP001643', 'LP001671', 'LP001734', 'LP001788',
#        'LP001865', 'LP001908', 'LP001998', 'LP002008', 'LP002036', 'LP002043',
#        'LP002055', 'LP002137', 'LP002178', 'LP002223', 'LP002263', 'LP002272',
#        'LP002319', 'LP002424', 'LP002447', 'LP002478', 'LP002522', 'LP002560',
#        'LP002562', 'LP002588', 'LP002624', 'LP002717', 'LP002757', 'LP002794',
#        'LP002833'],
#       dtype='object', name='Loan_ID')

# %%
Index_L2
# Out:
# Index(['LP001052', 'LP001091', 'LP001273', 'LP001326', 'LP001465', 'LP001634',
#        'LP001786', 'LP001864', 'LP002444', 'LP002618', 'LP002729', 'LP002898',
#        'LP002949'],
#       dtype='object', name='Loan_ID')

# %%
df_cat.loc[Index_L1,"Credit_History"]=1
df_cat.loc[Index_L2,"Credit_History"]=0
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
df_cat.isnull().sum()
# Out:
# Gender              13
# Married              3
# Dependents          15
# Education            0
# Self_Employed       32
# Loan_Amount_Term    14
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
# Removing "Self_Employed" column

# %%
df_cat.drop(['Self_Employed'], axis=1, inplace=True)
df_cat.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#          Gender Married Dependents     Education Loan_Amount_Term  \
# Loan_ID
# LP001002   Male      No        0.0      Graduate            360.0
# LP001003   Male     Yes        1.0      Graduate            360.0
# LP001005   Male     Yes        0.0      Graduate            360.0
# LP001006   Male     Yes        0.0  Not Graduate            360.0
# LP001008   Male      No        0.0      Graduate            360.0
#
#          Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002            1.0         Urban           Y
# LP001003            1.0         Rural           N
# LP001005            1.0         Urban           Y
# ...

# %%
df_cat.isnull().sum()
# Out:
# Gender              13
# Married              3
# Dependents          15
# Education            0
# Loan_Amount_Term    14
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
def cat_col_impute_mode(data_fr,cat_col):
  	data_fr[cat_col] = data_fr[cat_col].fillna(data_fr[cat_col].mode()[0])

# %%
for i in df_cat.columns.tolist():
  cat_col_impute_mode(df_cat,i)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_cat.isnull().sum()
# Out:
# Gender              0
# Married             0
# Dependents          0
# Education           0
# Loan_Amount_Term    0
# Credit_History      0
# Property_Area       0
# Loan_Status         0
# dtype: int64

# %%
df_numeric.isnull().sum()
# Out:
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# dtype: int64

# %%
actual_y=pd.DataFrame(df_cat['Loan_Status'],columns=['Loan_Status'])
actual_y.shape
# Out:
# (614, 1)

# %%
df_cat=df_cat.drop('Loan_Status',axis=1)
df_cat.head()
# Out:
#          Gender Married Dependents     Education  Loan_Amount_Term  \
# Loan_ID
# LP001002   Male      No        0.0      Graduate             360.0
# LP001003   Male     Yes        1.0      Graduate             360.0
# LP001005   Male     Yes        0.0      Graduate             360.0
# LP001006   Male     Yes        0.0  Not Graduate             360.0
# LP001008   Male      No        0.0      Graduate             360.0
#
#           Credit_History Property_Area
# Loan_ID
# LP001002             1.0         Urban
# LP001003             1.0         Rural
# LP001005             1.0         Urban
# LP001006             1.0         Urban
# LP001008             1.0         Urban

# %%
df_train=df_numeric.join(df_cat)
df_train.head()
# Out:
#           ApplicantIncome  CoapplicantIncome  LoanAmount Gender Married  \
# Loan_ID
# LP001002           5849.0                0.0       128.0   Male      No
# LP001003           4583.0             1508.0       128.0   Male     Yes
# LP001005           3000.0                0.0        66.0   Male     Yes
# LP001006           2583.0             2358.0       120.0   Male     Yes
# LP001008           6000.0                0.0       141.0   Male      No
#
#          Dependents     Education  Loan_Amount_Term  Credit_History  \
# Loan_ID
# LP001002        0.0      Graduate             360.0             1.0
# LP001003        1.0      Graduate             360.0             1.0
# LP001005        0.0      Graduate             360.0             1.0
# LP001006        0.0  Not Graduate             360.0             1.0
# LP001008        0.0      Graduate             360.0             1.0
#
#          Property_Area
# Loan_ID
# LP001002         Urban
# LP001003         Rural
# ...

# %%
df_train.shape
# Out:
# (614, 10)

# %%
df_train.isnull().sum()
# Out:
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
# Encoding for Categorical Variables

# %%
df_cat.head()
# Out:
#          Gender Married Dependents     Education  Loan_Amount_Term  \
# Loan_ID
# LP001002   Male      No        0.0      Graduate             360.0
# LP001003   Male     Yes        1.0      Graduate             360.0
# LP001005   Male     Yes        0.0      Graduate             360.0
# LP001006   Male     Yes        0.0  Not Graduate             360.0
# LP001008   Male      No        0.0      Graduate             360.0
#
#           Credit_History Property_Area
# Loan_ID
# LP001002             1.0         Urban
# LP001003             1.0         Rural
# LP001005             1.0         Urban
# LP001006             1.0         Urban
# LP001008             1.0         Urban

# %%
'''
Binary---> Gender, Married, Education, Credit_History
Ordinal--> Dependents, Loan_Amount_Term
OneHot---> Property_Area
'''
# Out:
# '\nBinary---> Gender, Married, Education, Credit_History\nOrdinal--> Dependents, Loan_Amount_Term\nOneHot---> Property_Area\n'

# %%
# OneHot---> Property_Area
ohe_data = pd.get_dummies(df_cat, columns = ['Property_Area'])
ohe_data.head()
# Out:
#          Gender Married Dependents     Education  Loan_Amount_Term  \
# Loan_ID
# LP001002   Male      No        0.0      Graduate             360.0
# LP001003   Male     Yes        1.0      Graduate             360.0
# LP001005   Male     Yes        0.0      Graduate             360.0
# LP001006   Male     Yes        0.0  Not Graduate             360.0
# LP001008   Male      No        0.0      Graduate             360.0
#
#           Credit_History  Property_Area_Rural  Property_Area_Semiurban  \
# Loan_ID
# LP001002             1.0                    0                        0
# LP001003             1.0                    1                        0
# LP001005             1.0                    0                        0
# LP001006             1.0                    0                        0
# LP001008             1.0                    0                        0
#
#           Property_Area_Urban
# Loan_ID
# LP001002                    1
# LP001003                    0
# ...

# %%
# Ordinal--> Dependents, Loan_Amount_Term

# %%
ohe_data["Loan_Amount_Term"].value_counts(ascending=True)
# Out:
# 12.0       1
# 60.0       2
# 36.0       2
# 120.0      3
# 240.0      4
# 84.0       4
# 300.0     13
# 480.0     15
# 180.0     44
# 360.0    526
# Name: Loan_Amount_Term, dtype: int64

# %%
lat_dict={12.0:1, 60.0:3, 36.0: 2, 120.0: 5, 240.0: 7, 84.0: 4,
          300.0: 8, 480.0: 10, 180.0: 6, 360.0: 9}
ohe_data["Ordinal_Loan_Amount_Term"]=ohe_data.Loan_Amount_Term.map(lat_dict)
ohe_data.drop('Loan_Amount_Term',axis=1,inplace=True)
ohe_data.head()
# Out:
#          Gender Married Dependents     Education  Credit_History  \
# Loan_ID
# LP001002   Male      No        0.0      Graduate             1.0
# LP001003   Male     Yes        1.0      Graduate             1.0
# LP001005   Male     Yes        0.0      Graduate             1.0
# LP001006   Male     Yes        0.0  Not Graduate             1.0
# LP001008   Male      No        0.0      Graduate             1.0
#
#           Property_Area_Rural  Property_Area_Semiurban  Property_Area_Urban  \
# Loan_ID
# LP001002                    0                        0                    1
# LP001003                    1                        0                    0
# LP001005                    0                        0                    1
# LP001006                    0                        0                    1
# LP001008                    0                        0                    1
#
#           Ordinal_Loan_Amount_Term
# Loan_ID
# LP001002                         9
# ...

# %%
ohe_data.Dependents.value_counts()
# Out:
# 0.0    360
# 1.0    102
# 2.0    101
# 3+      51
# Name: Dependents, dtype: int64

# %%
Dependents_dict={'3+':1, 2.0:2, 1.0:3, 0.0:4}
ohe_data["Ordinal_Dependents"]=ohe_data.Dependents.map(Dependents_dict)
ohe_data.drop('Dependents',axis=1,inplace=True)
ohe_data.head()
# Out:
#          Gender Married     Education  Credit_History  Property_Area_Rural  \
# Loan_ID
# LP001002   Male      No      Graduate             1.0                    0
# LP001003   Male     Yes      Graduate             1.0                    1
# LP001005   Male     Yes      Graduate             1.0                    0
# LP001006   Male     Yes  Not Graduate             1.0                    0
# LP001008   Male      No      Graduate             1.0                    0
#
#           Property_Area_Semiurban  Property_Area_Urban  \
# Loan_ID
# LP001002                        0                    1
# LP001003                        0                    0
# LP001005                        0                    1
# LP001006                        0                    1
# LP001008                        0                    1
#
#           Ordinal_Loan_Amount_Term  Ordinal_Dependents
# Loan_ID
# LP001002                         9                   4
# ...

# %%
# Binary---> Gender, Married, Education

# %%
pip install category_encoders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 72 kB 585 kB/s
# ...

# %%
import category_encoders as ce

# %%
ce_OHE = ce.OneHotEncoder(cols=['Gender', 'Married', 'Education']) 

ohe_data = ce_OHE.fit_transform(ohe_data)
ohe_data.head()
# Out:
#           Gender_1  Gender_2  Married_1  Married_2  Education_1  Education_2  \
# Loan_ID
# LP001002         1         0          1          0            1            0
# LP001003         1         0          0          1            1            0
# LP001005         1         0          0          1            1            0
# LP001006         1         0          0          1            0            1
# LP001008         1         0          1          0            1            0
#
#           Credit_History  Property_Area_Rural  Property_Area_Semiurban  \
# Loan_ID
# LP001002             1.0                    0                        0
# LP001003             1.0                    1                        0
# LP001005             1.0                    0                        0
# LP001006             1.0                    0                        0
# LP001008             1.0                    0                        0
#
# ...

# %%
# Standardizing/ Normalizing numerical data

# %%
df_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 614 entries, LP001002 to LP002990
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ApplicantIncome    614 non-null    float64
#  1   CoapplicantIncome  614 non-null    float64
#  2   LoanAmount         614 non-null    float64
# dtypes: float64(3)
# memory usage: 35.4+ KB

# %%
df_numeric.head()
# Out:
#           ApplicantIncome  CoapplicantIncome  LoanAmount
# Loan_ID
# LP001002           5849.0                0.0       128.0
# LP001003           4583.0             1508.0       128.0
# LP001005           3000.0                0.0        66.0
# LP001006           2583.0             2358.0       120.0
# LP001008           6000.0                0.0       141.0

# %%
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler(feature_range=(0, 1))

df_numeric[['ApplicantIncome','CoapplicantIncome','LoanAmount']] = mms.fit_transform(df_numeric[['ApplicantIncome','CoapplicantIncome','LoanAmount']])
df_numeric.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
#           ApplicantIncome  CoapplicantIncome  LoanAmount
# Loan_ID
# LP001002         0.070489           0.000000    0.172214
# LP001003         0.054830           0.036192    0.172214
# LP001005         0.035250           0.000000    0.082489
# LP001006         0.030093           0.056592    0.160637
# LP001008         0.072356           0.000000    0.191027

# %%
df_train=df_numeric.join(ohe_data)
df_train.head()
# Out:
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Gender_1  Gender_2  \
# Loan_ID
# LP001002         0.070489           0.000000    0.172214         1         0
# LP001003         0.054830           0.036192    0.172214         1         0
# LP001005         0.035250           0.000000    0.082489         1         0
# LP001006         0.030093           0.056592    0.160637         1         0
# LP001008         0.072356           0.000000    0.191027         1         0
#
#           Married_1  Married_2  Education_1  Education_2  Credit_History  \
# Loan_ID
# LP001002          1          0            1            0             1.0
# LP001003          0          1            1            0             1.0
# LP001005          0          1            1            0             1.0
# LP001006          0          1            0            1             1.0
# LP001008          1          0            1            0             1.0
#
# ...

# %%
df_train.shape
# Out:
# (614, 15)

# %%
df.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No        0.0      Graduate            No
# LP001003   Male     Yes        1.0      Graduate            No
# LP001005   Male     Yes        0.0      Graduate           Yes
# LP001006   Male     Yes        0.0  Not Graduate            No
# LP001008   Male      No        0.0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount Loan_Amount_Term  \
# Loan_ID
# LP001002           5849.0                0.0         NaN            360.0
# LP001003           4583.0             1508.0       128.0            360.0
# LP001005           3000.0                0.0        66.0            360.0
# LP001006           2583.0             2358.0       120.0            360.0
# LP001008           6000.0                0.0       141.0            360.0
#
#          Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002            1.0         Urban           Y
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 614 entries, LP001002 to LP002990
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ApplicantIncome           614 non-null    float64
#  1   CoapplicantIncome         614 non-null    float64
#  2   LoanAmount                614 non-null    float64
#  3   Gender_1                  614 non-null    int64
#  4   Gender_2                  614 non-null    int64
#  5   Married_1                 614 non-null    int64
#  6   Married_2                 614 non-null    int64
#  7   Education_1               614 non-null    int64
#  8   Education_2               614 non-null    int64
#  9   Credit_History            614 non-null    float64
#  10  Property_Area_Rural       614 non-null    uint8
#  11  Property_Area_Semiurban   614 non-null    uint8
#  12  Property_Area_Urban       614 non-null    uint8
# ...

# %%
actual_y.shape
# Out:
# (614, 1)

# %%
actual_y.head()
# Out:
#          Loan_Status
# Loan_ID
# LP001002           Y
# LP001003           N
# LP001005           Y
# LP001006           Y
# LP001008           Y

# %%
# Logistic regression

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
model=LogisticRegression(max_iter=100,solver='saga')
params={'C':[1,0.1,5,100,2,0.8],
        'penalty':['l1','l2','elasticnet']
        }
gcv=GridSearchCV(model,param_grid=params,cv=5,scoring='accuracy')

# %%
gcv.fit(df_train,actual_y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# ...

# %%
gcv.best_params_
# Out:
# {'C': 1, 'penalty': 'l1'}

# %%
gcv.best_score_
# Out:
# 0.8306544049047048

# %%
# KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()
from sklearn.model_selection import GridSearchCV
params={'n_neighbors':[1,2,3,4,5,6],
        'metric':['cosine','l1','euclidean']}

gcv=GridSearchCV(model,param_grid=params,cv=5,scoring='accuracy')
gcv.fit(df_train,actual_y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
gcv.best_params_
# Out:
# {'metric': 'cosine', 'n_neighbors': 5}

# %%
gcv.best_score_
# Out:
# 0.7916033586565374

# %%
# Decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(random_state=3)
params={'criterion':['entropy','gini','logloss'],
        'splitter':['best','random'],
        'max_depth':[5,6,7,8,9],
        'min_samples_split':[7,8,9],
        'min_samples_leaf':[1,3,5],
        'max_features':['sqrt',3,5,6,7]
        }
gcv=GridSearchCV(model,cv=5,param_grid=params)
gcv.fit(df_train,actual_y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 2250 fits failed out of a total of 6750.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2250 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py", line 942, in fit
#     X_idx_sorted=X_idx_sorted,
#   File "/usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'logloss'
#
# ...

# %%
gcv.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 5,
#  'max_features': 6,
#  'min_samples_leaf': 1,
#  'min_samples_split': 7,
#  'splitter': 'best'}

# %%
gcv.best_score_
# Out:
# 0.8274023723843795

# %%
#default tree

# %%
import numpy as np
from sklearn.model_selection import KFold,cross_val_score
kf=KFold(n_splits=10)
model=DecisionTreeClassifier(random_state=3)
np.array(cross_val_score(model,df_train,actual_y,scoring='accuracy',cv=kf))
# Out:
# array([0.74193548, 0.83870968, 0.74193548, 0.77419355, 0.60655738,
#        0.7704918 , 0.72131148, 0.75409836, 0.6557377 , 0.75409836])

# %%
# Support Vector Classifier

# %%
from sklearn.svm import SVC
model=SVC()
params={'C':[1,0.1,5,10,100,2,0.8],
        'kernel':['poly','rbf','linear','sigmoid']
        }
gcv=GridSearchCV(model,param_grid=params,cv=5)
gcv.fit(df_train,actual_y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
gcv.best_params_
# Out:
# {'C': 1, 'kernel': 'rbf'}

# %%
gcv.best_score_
# Out:
# 0.8306544049047048

# %%
# RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
from sklearn.model_selection import GridSearchCV

params={'n_estimators':[10,20,30,40,50],
        'criterion':['gini','entropy'],
        'max_features':['sqrt',10,20,30,64],
        'max_samples':[0.5,0.7,0.8]    
}
gcv=GridSearchCV(model,cv=3,param_grid=params,scoring='accuracy')
gcv.fit(df_train,actual_y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
gcv.best_score_
# Out:
# 0.8143312609596686

# %%
gcv.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_features': 'sqrt',
#  'max_samples': 0.7,
#  'n_estimators': 50}

# %%
df_cat.loc[df_cat[(df_cat.isnull().sum(axis=1) >=2)].index]
# Out:
# Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Loan_Amount_Term, Credit_History, Property_Area]
# Index: []
